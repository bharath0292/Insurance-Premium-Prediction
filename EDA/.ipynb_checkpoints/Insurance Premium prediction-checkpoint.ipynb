# %%
import numpy as np
import pandas as pd
import matplotlib as plt
# %matplotlib inline
import seaborn as sns

# %%
#Load the data 
data = pd.read_csv("insurance.csv")

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# Lets See Age vs expences 
data.plot.scatter(x = 'age', y = 'expenses')
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
# Lets see expences by gender 
ax = sns.barplot("sex", "expenses",data=data)

# %% [markdown]
# # Data Transformation

# %%
# Let's copy our data and do the transformation operation
DataUpdated = data.copy()
DataUpdated
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
# Let's encode the sex coloumn
DataUpdated['sex'] = DataUpdated['sex'].map({'female' : 0, 'male' : 1})
DataUpdated
# Out:
#       age  sex   bmi  children smoker     region  expenses
# 0      19    0  27.9         0    yes  southwest  16884.92
# 1      18    1  33.8         1     no  southeast   1725.55
# 2      28    1  33.0         3     no  southeast   4449.46
# 3      33    1  22.7         0     no  northwest  21984.47
# 4      32    1  28.9         0     no  northwest   3866.86
# ...   ...  ...   ...       ...    ...        ...       ...
# 1333   50    1  31.0         3     no  northwest  10600.55
# 1334   18    0  31.9         0     no  northeast   2205.98
# 1335   18    0  36.9         0     no  southeast   1629.83
# 1336   21    0  25.8         0     no  southwest   2007.95
# 1337   61    0  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
# Let's encode the sex coloumn
DataUpdated['smoker'] = DataUpdated['smoker'].map({'no' : 0, 'yes' : 1})
DataUpdated
# Out:
#       age  sex   bmi  children  smoker     region  expenses
# 0      19    0  27.9         0       1  southwest  16884.92
# 1      18    1  33.8         1       0  southeast   1725.55
# 2      28    1  33.0         3       0  southeast   4449.46
# 3      33    1  22.7         0       0  northwest  21984.47
# 4      32    1  28.9         0       0  northwest   3866.86
# ...   ...  ...   ...       ...     ...        ...       ...
# 1333   50    1  31.0         3       0  northwest  10600.55
# 1334   18    0  31.9         0       0  northeast   2205.98
# 1335   18    0  36.9         0       0  southeast   1629.83
# 1336   21    0  25.8         0       0  southwest   2007.95
# 1337   61    0  29.1         0       1  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
dataUpdated = pd.concat([pd.get_dummies(DataUpdated.region), DataUpdated.iloc[:,[1,2,3,4,6]]] , axis = 1)
dataUpdated
# Out:
#       northeast  northwest  southeast  southwest  sex   bmi  children  smoker  \
# 0             0          0          0          1    0  27.9         0       1
# 1             0          0          1          0    1  33.8         1       0
# 2             0          0          1          0    1  33.0         3       0
# 3             0          1          0          0    1  22.7         0       0
# 4             0          1          0          0    1  28.9         0       0
# ...         ...        ...        ...        ...  ...   ...       ...     ...
# 1333          0          1          0          0    1  31.0         3       0
# 1334          1          0          0          0    0  31.9         0       0
# 1335          0          0          1          0    0  36.9         0       0
# 1336          0          0          0          1    0  25.8         0       0
# 1337          0          1          0          0    0  29.1         0       1
#
#       expenses
# 0     16884.92
# ...

# %%
# # As region has some value here so we do label Encoder
# from sklearn.preprocessing import LabelEncoder
# regionEncoder = LabelEncoder()
# regionEncoder.fit(DataUpdated['region'])
# DataUpdated['region'] = regionEncoder.transform(DataUpdated['region'])
# DataUpdated

# %% [markdown]
# # Outlier Detection

# %%
DataUpdated.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.494768    30.665471     1.094918     0.204783
# std      14.049960     0.500160     6.098382     1.205493     0.403694
# min      18.000000     0.000000    16.000000     0.000000     0.000000
# 25%      27.000000     0.000000    26.300000     0.000000     0.000000
# 50%      39.000000     0.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.700000     2.000000     0.000000
# max      64.000000     1.000000    53.100000     5.000000     1.000000
#
#             region      expenses
# count  1338.000000   1338.000000
# mean      1.515695  13270.422414
# std       1.104885  12110.011240
# min       0.000000   1121.870000
# 25%       1.000000   4740.287500
# 50%       2.000000   9382.030000
# 75%       2.000000  16639.915000
# max       3.000000  63770.430000

# %%
# It looks like their is no outlier in feature column

# %% [markdown]
# # EDA

# %%
# Correlation Heatmaps
sns.heatmap(DataUpdated.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# Boxplot for outliers
sns.boxplot(data=DataUpdated[["age", "bmi",]]);

# %%
sns.boxplot(data=DataUpdated)
# Out:
# <AxesSubplot:>

# %%
# Piecharts for categories

# %%
sns.pairplot(data, hue="sex")

# %% [markdown]
# # Line plot

# %%
ages = DataUpdated.groupby("age").median().reset_index()
ages.head()
# Out:
#    age  sex   bmi  children  smoker  region  expenses
# 0   18  0.0  31.4       0.0     0.0     2.0  2198.190
# 1   19  0.0  28.5       0.0     0.0     1.5  2135.890
# 2   20  0.0  30.7       0.0     0.0     2.0  2459.720
# 3   21  0.0  26.9       0.0     0.0     1.5  2254.420
# 4   22  0.0  30.7       0.0     0.0     1.5  2641.155

# %%
ages.plot.line("age", "expenses");

# %%
ages.plot.line("age", "bmi");

# %%
sns.lineplot("age", "expenses", data=ages);

# %% [markdown]
# # ML Model creation

# %%
# Seperate the data as features and label

features = DataUpdated.iloc[:,:-1].values
label = DataUpdated.expenses.values

# %%
sns.distplot(features[:,2])
# Out:
# <AxesSubplot:>

# %%
# Standardize the data

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
features = sc.fit_transform(features)
features
# Out:
# array([[-1.43876426,  1.0105187 , -0.4536457 , -0.90861367,  1.97058663,
#          1.34390459],
#        [-1.50996545, -0.98959079,  0.51418574, -0.07876719, -0.5074631 ,
#          0.43849455],
#        [-0.79795355, -0.98959079,  0.38295436,  1.58092576, -0.5074631 ,
#          0.43849455],
#        ...,
#        [-1.50996545,  1.0105187 ,  1.02270734, -0.90861367, -0.5074631 ,
#          0.43849455],
#        [-1.29636188,  1.0105187 , -0.79812808, -0.90861367, -0.5074631 ,
#          1.34390459],
#        [ 1.55168573,  1.0105187 , -0.25679863, -0.90861367,  1.97058663,
#         -0.46691549]])

# %%
#features = features.reshape(-1,1)
label = label.reshape(-1,1)

# %%
features.shape
# Out:
# (1338, 6)

# %%
label.shape
# Out:
# (1338, 1)

# %%
#Create Train Test Split

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(features,
                                                 label,
                                                 test_size=0.2,
                                                 random_state=2)

# %%
# Linear Regression
